# %% [markdown]
# In this section, we'll investigate some of the typical problems in fMRI data, such as the effects of subject motion and physiological noise, and the algorithms that are often used to fix them.

# %% [markdown]
# First we need to set up our environment with some now-familiar imports.

# %%
# %pylab inline
import os # Module with commands to interact with the operating system
import numpy as np # this is the Python package for handling arrays
import matplotlib.pyplot as plt # This is for making 2D plots like MATLAB
import nibabel as nib
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# Now let's load a time series of images and check the temporal stability.

# %%
DATA_DIR = os.path.abspath('ds107') # The absolute path to the data directory
SUBJ1_DIR = os.path.join(DATA_DIR, 'sub001')
s1_bold_fname = os.path.join(SUBJ1_DIR, 'BOLD', 'task001_run001', 'bold.nii.gz')
s1_bold_img = nib.load(s1_bold_fname)
s1_bold_arr = s1_bold_img.get_data()

# %% [markdown]
# Show the temporal standard deviation. This will indicate spatial regions that have high temporal fluctuations.

# %%
time_course_std = s1_bold_arr.std(axis=3) # the last axis (0-based numbering)
plt.imshow(time_course_std[:, :, 17])

# %% [markdown]
# Computing the temporal standard devaition collapses across time. Now let's comute a metric that will collapse across space. This will help us see temporal regions that have high variance. We'll use the root mean square error between each adjacent pair of time points.

# %%
num_timepoints = s1_bold_arr.shape[3]
rms = np.zeros(num_timepoints) # initialize an array to hold our rms values
temporal_mean = s1_bold_arr.mean(axis=3)
for t in range(num_timepoints):
    squared_difference = (temporal_mean - s1_bold_arr[:,:,:,t])**2
    rms[t] = np.sqrt(np.mean(squared_difference))
plt.plot(rms)

# %% [markdown]
# Now let's do the same for all the subjects. First we'll get a list of all the subject data directories.

# %%
all_subs = os.listdir(DATA_DIR)
all_subs
# Out:
# ['sub002',
#  'sub038',
#  'sub013',
#  'sub003',
#  'sub020',
#  'sub023',
#  'sub025',
#  'sub041',
#  'sub001',
#  'sub037',
#  'sub026',
#  'sub046',
#  'sub042',
#  'sub030',
#  'sub016',
#  'sub040',
#  'task_key.txt',
#  'sub047',
#  'sub039',
#  'sub017',
#  'sub018',
#  'sub012',
#  'sub006',
#  'sub031',
#  'sub011',
#  'sub009',
#  'sub005',
#  'sub010',
#  'sub022',
#  'sub015',
#  'sub021',
#  'sub028',
#  'sub032',
#  'sub029',
#  'sub004',
#  'sub019',
#  'sub033',
#  'sub035',
#  'sub043',
#  'scan_key.txt',
#  'sub049',
#  'sub045',
#  'sub027',
#  'sub044',
#  'models',
#  'sub024',
#  'sub034',
#  'sub007',
#  'sub048',
#  'sub014',
#  'sub036',
#  'sub008']

# %% [markdown]
# Oops-- there are a couple of other files in there. We'll use a powerful tool in python called a list comprehension to get a clean lisr of subject directories:

# %%
all_subs = [s for s in os.listdir(DATA_DIR) if "sub" in s]
all_subs
# Out:
# ['sub002',
#  'sub038',
#  'sub013',
#  'sub003',
#  'sub020',
#  'sub023',
#  'sub025',
#  'sub041',
#  'sub001',
#  'sub037',
#  'sub026',
#  'sub046',
#  'sub042',
#  'sub030',
#  'sub016',
#  'sub040',
#  'sub047',
#  'sub039',
#  'sub017',
#  'sub018',
#  'sub012',
#  'sub006',
#  'sub031',
#  'sub011',
#  'sub009',
#  'sub005',
#  'sub010',
#  'sub022',
#  'sub015',
#  'sub021',
#  'sub028',
#  'sub032',
#  'sub029',
#  'sub004',
#  'sub019',
#  'sub033',
#  'sub035',
#  'sub043',
#  'sub049',
#  'sub045',
#  'sub027',
#  'sub044',
#  'sub024',
#  'sub034',
#  'sub007',
#  'sub048',
#  'sub014',
#  'sub036',
#  'sub008']

# %%
num_subjects = len(all_subs)
rms_all = np.zeros((num_subjects, num_timepoints)) # initialize an array to hold our rms values
# We assume that all subject have the same exact image dimensions. In this dataset, 
# some subjects have a few extra timepoints. (???) We'll just ignore that.
for sub_index,sub_dir in enumerate(all_subs):
    bold_fname = os.path.join(DATA_DIR, sub_dir, 'BOLD', 'task001_run001', 'bold.nii.gz')
    bold_arr = nib.load(bold_fname).get_data()
    temporal_mean = bold_arr.mean(axis=3)
    for t in range(num_timepoints):
        squared_difference = (temporal_mean - bold_arr[:,:,:,t])**2
        rms_all[sub_index,t] = np.sqrt(np.mean(squared_difference))

# %% [markdown]
# Now plot the results.

# %%
for rms_s in rms_all:
    plt.plot(rms_s)

# %% [markdown]
# It looks like some subjects have some time points with very large deviations. There also appears to be a trend across all the subjects:

# %%
plt.plot(rms_all.mean(axis=0))

# %% [markdown]
# There is much more deviation at the beginning and end of the run. Why is that? One possibility is motion. Let's motion-correct the worst subject's data and then have another look. First, we have to find that subject:

# %%
mean_rms_all = rms_all.mean(axis=1)
worst_subject = np.nonzero(mean_rms_all==mean_rms_all.max())[0][0]
worst_subject
# Out:
# 4

# %%
from nipy.algorithms import registration
# Out:
#   File "<ipython-input-27-1f9810b2d230>", line 2
#     nipy.algorithms.registration.FmriRealign4d(
#                                                ^
# SyntaxError: invalid syntax

# %%
worst_bold_fname = os.path.join(DATA_DIR, all_subs[worst_subject], 'BOLD', 'task001_run001', 'bold.nii.gz')
worst_bold_img = nib.load(worst_bold_fname)

# %% [markdown]
# To properly do the slice-time correction, we need to know the slice acquisition order. Ideally, you will get this from the image header. Unfortunately, that information is not always set properly, as in the data that we are analyzing:

# %%
worst_bold_img.get_header().get_slice_times()
# Out:
# ---------------------------------------------------------------------------
# HeaderDataError                           Traceback (most recent call last)
# <ipython-input-36-9a75d08a0d4f> in <module>()
# ----> 1 worst_bold_img.get_header().get_slice_times()
#
# /usr/lib/pymodules/python2.7/nibabel/nifti1.pyc in get_slice_times(self)
#    1273         '''
#    1274         hdr = self._structarr
# -> 1275         slice_len = self.get_n_slices()
#    1276         duration = self.get_slice_duration()
#    1277         slabel = self.get_value_label('slice_code')
#
# /usr/lib/pymodules/python2.7/nibabel/nifti1.pyc in get_n_slices(self)
#    1237         _, _, slice_dim = self.get_dim_info()
#    1238         if slice_dim is None:
# -> 1239             raise HeaderDataError('Slice dimension not set in header '
#    1240                                   'dim_info')
#    1241         shape = self.get_data_shape()
#
# HeaderDataError: Slice dimension not set in header dim_info

# %% [markdown]
# If the header isn't set properly, then you just need to know how the data were acquired.

# %%
slice_order = range(worst_bold_img.get_shape()[2])

# %% [markdown]
# WRITEME

# %%
xyzt = worst_bold_img.get_header().get_zooms()

# %% [markdown]
# WRITEME

# %%
realign = nipy.algorithms.registration.FmriRealign4d(worst_bold_img, slice_order, tr=xyzt[3])

# %% [markdown]
# WRITEME

# %%
realign.estimate(loops=3)
# Out:
# Resampling scan 1/165
# Resampling scan 2/165
# Resampling scan 3/165
# Resampling scan 4/165
# Resampling scan 5/165
# Resampling scan 6/165
# Resampling scan 7/165
# Resampling scan 8/165
# Resampling scan 9/165
# Resampling scan 10/165
# Resampling scan 11/165
# Resampling scan 12/165
# Resampling scan 13/165
# Resampling scan 14/165
# Resampling scan 15/165
# Resampling scan 16/165
# Resampling scan 17/165
# Resampling scan 18/165
# Resampling scan 19/165
# Resampling scan 20/165
# Resampling scan 21/165
# Resampling scan 22/165
# Resampling scan 23/165
# Resampling scan 24/165
# Resampling scan 25/165
# Resampling scan 26/165
# Resampling scan 27/165
# Resampling scan 28/165
# Resampling scan 29/165
# Resampling scan 30/165
# Resampling scan 31/165
# Resampling scan 32/165
# Resampling scan 33/165
# Resampling scan 34/165
# Resampling scan 35/165
# Resampling scan 36/165
# Resampling scan 37/165
# Resampling scan 38/165
# Resampling scan 39/165
# Resampling scan 40/165
# Resampling scan 41/165
# Resampling scan 42/165
# Resampling scan 43/165
# Resampling scan 44/165
# Resampling scan 45/165
# Resampling scan 46/165
# Resampling scan 47/165
# Resampling scan 48/165
# Resampling scan 49/165
# Resampling scan 50/165
# Resampling scan 51/165
# Resampling scan 52/165
# Resampling scan 53/165
# Resampling scan 54/165
# Resampling scan 55/165
# Resampling scan 56/165
# Resampling scan 57/165
# Resampling scan 58/165
# Resampling scan 59/165
# Resampling scan 60/165
# Resampling scan 61/165
# Resampling scan 62/165
# Resampling scan 63/165
# Resampling scan 64/165
# Resampling scan 65/165
# Resampling scan 66/165
# Resampling scan 67/165
# Resampling scan 68/165
# Resampling scan 69/165
# Resampling scan 70/165
# Resampling scan 71/165
# Resampling scan 72/165
# Resampling scan 73/165
# Resampling scan 74/165
# Resampling scan 75/165
# Resampling scan 76/165
# Resampling scan 77/165
# Resampling scan 78/165
# Resampling scan 79/165
# Resampling scan 80/165
# Resampling scan 81/165
# Resampling scan 82/165
# Resampling scan 83/165
# Resampling scan 84/165
# Resampling scan 85/165
# Resampling scan 86/165
# Resampling scan 87/165
# Resampling scan 88/165
# Resampling scan 89/165
# Resampling scan 90/165
# Resampling scan 91/165
# Resampling scan 92/165
# Resampling scan 93/165
# Resampling scan 94/165
# Resampling scan 95/165
# Resampling scan 96/165
# Resampling scan 97/165
# Resampling scan 98/165
# Resampling scan 99/165
# Resampling scan 100/165
# Resampling scan 101/165
# Resampling scan 102/165
# Resampling scan 103/165
# Resampling scan 104/165
# Resampling scan 105/165
# Resampling scan 106/165
# Resampling scan 107/165
# Resampling scan 108/165
# Resampling scan 109/165
# Resampling scan 110/165
# Resampling scan 111/165
# Resampling scan 112/165
# Resampling scan 113/165
# Resampling scan 114/165
# Resampling scan 115/165
# Resampling scan 116/165
# Resampling scan 117/165
# Resampling scan 118/165
# Resampling scan 119/165
# Resampling scan 120/165
# Resampling scan 121/165
# Resampling scan 122/165
# Resampling scan 123/165
# Resampling scan 124/165
# Resampling scan 125/165
# Resampling scan 126/165
# Resampling scan 127/165
# Resampling scan 128/165
# Resampling scan 129/165
# Resampling scan 130/165
# Resampling scan 131/165
# Resampling scan 132/165
# Resampling scan 133/165
# Resampling scan 134/165
# Resampling scan 135/165
# Resampling scan 136/165
# Resampling scan 137/165
# Resampling scan 138/165
# Resampling scan 139/165
# Resampling scan 140/165
# Resampling scan 141/165
# Resampling scan 142/165
# Resampling scan 143/165
# Resampling scan 144/165
# Resampling scan 145/165
# Resampling scan 146/165
# Resampling scan 147/165
# Resampling scan 148/165
# Resampling scan 149/165
# Resampling scan 150/165
# Resampling scan 151/165
# Resampling scan 152/165
# Resampling scan 153/165
# Resampling scan 154/165
# Resampling scan 155/165
# Resampling scan 156/165
# Resampling scan 157/165
# Resampling scan 158/165
# Resampling scan 159/165
# Resampling scan 160/165
# Resampling scan 161/165
# Resampling scan 162/165
# Resampling scan 163/165
# Resampling scan 164/165
# Resampling scan 165/165
# Estimating motion at time frame 1/165...
# Optimization terminated successfully.
#          Current function value: -4.533594
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.26516518  0.59908461  0.00551416]
# rotation    : [-0.01206728 -0.0010269   0.0069192 ]
#
# Estimating motion at time frame 2/165...
# Optimization terminated successfully.
#          Current function value: -4.538026
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.25586893  0.62357535  0.01945455]
# rotation    : [-0.01170368 -0.00043335  0.00792302]
#
# Estimating motion at time frame 3/165...
# Optimization terminated successfully.
#          Current function value: -4.542680
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.34635364  0.6331431   0.09847446]
# rotation    : [-0.01072389 -0.00191555  0.00885197]
#
# Estimating motion at time frame 4/165...
# Optimization terminated successfully.
#          Current function value: -4.547748
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 6
#          Hessian evaluations: 6
# translation : [-0.35542328  0.61920935  0.10529438]
# rotation    : [-0.01103298 -0.00338547  0.00953408]
#
# Estimating motion at time frame 5/165...
# Optimization terminated successfully.
#          Current function value: -4.552343
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.36416437  0.57363381  0.13214884]
# rotation    : [-0.00998544 -0.0038018   0.01012288]
#
# Estimating motion at time frame 6/165...
# Optimization terminated successfully.
#          Current function value: -4.556690
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.3491308   0.58841006  0.14979054]
# rotation    : [-0.00924294 -0.00298135  0.00952755]
#
# Estimating motion at time frame 7/165...
# Optimization terminated successfully.
#          Current function value: -4.560694
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.33299467  0.58278775  0.14197671]
# rotation    : [-0.00866552 -0.00322429  0.00906677]
#
# Estimating motion at time frame 8/165...
# Optimization terminated successfully.
#          Current function value: -4.564553
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.34655791  0.54693139  0.18836634]
# rotation    : [-0.00739361 -0.00335242  0.00933032]
#
# Estimating motion at time frame 9/165...
# Optimization terminated successfully.
#          Current function value: -4.567910
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.30076134  0.54782412  0.22128687]
# rotation    : [-0.00580647 -0.00284718  0.00918408]
#
# Estimating motion at time frame 10/165...
# Optimization terminated successfully.
#          Current function value: -4.571714
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.34807226  0.54519805  0.21679577]
# rotation    : [-0.00519827 -0.00320539  0.01052015]
#
# Estimating motion at time frame 11/165...
# Optimization terminated successfully.
#          Current function value: -4.575173
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.36698399  0.50673059  0.25206804]
# rotation    : [-0.00435474 -0.00376083  0.01064963]
#
# Estimating motion at time frame 12/165...
# Optimization terminated successfully.
#          Current function value: -4.578182
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.32921939  0.4862759   0.26940582]
# rotation    : [-0.00299962 -0.00422917  0.00940067]
#
# Estimating motion at time frame 13/165...
# Optimization terminated successfully.
#          Current function value: -4.581121
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.36957205  0.44098685  0.24949919]
# rotation    : [-0.00342516 -0.00528799  0.00946645]
#
# Estimating motion at time frame 14/165...
# Optimization terminated successfully.
#          Current function value: -4.584518
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.39783537  0.48591438  0.13432989]
# rotation    : [-0.00492581 -0.00407288  0.01144642]
#
# Estimating motion at time frame 15/165...
# Optimization terminated successfully.
#          Current function value: -4.588835
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.46272246  0.53057382 -0.13593549]
# rotation    : [-0.00925221 -0.00268679  0.01346015]
#
# Estimating motion at time frame 16/165...
# Optimization terminated successfully.
#          Current function value: -4.590933
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.32759587  0.37437819 -0.14632568]
# rotation    : [-0.00209508  0.00264599  0.01084289]
#
# Estimating motion at time frame 17/165...
# Optimization terminated successfully.
#          Current function value: -4.593360
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.39209893  0.38145565 -0.14236352]
# rotation    : [-0.00282687  0.0008832   0.01098931]
#
# Estimating motion at time frame 18/165...
# Optimization terminated successfully.
#          Current function value: -4.596809
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.53262979  0.43443228 -0.16654166]
# rotation    : [-0.00431953 -0.00150381  0.01228485]
#
# Estimating motion at time frame 19/165...
# Optimization terminated successfully.
#          Current function value: -4.600445
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.54751974  0.46312094 -0.08103111]
# rotation    : [-0.00368147 -0.00182038  0.01248615]
#
# Estimating motion at time frame 20/165...
# Optimization terminated successfully.
#          Current function value: -4.604235
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.54504417  0.44423195 -0.04299609]
# rotation    : [-0.00345251 -0.00244674  0.0129693 ]
#
# Estimating motion at time frame 21/165...
# Optimization terminated successfully.
#          Current function value: -4.607939
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.53479401  0.43122787 -0.04918346]
# rotation    : [-0.00357738 -0.00374452  0.01293092]
#
# Estimating motion at time frame 22/165...
# Optimization terminated successfully.
#          Current function value: -4.611791
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.54005148  0.43243974 -0.05707551]
# rotation    : [-0.00330988 -0.00299057  0.01356017]
#
# Estimating motion at time frame 23/165...
# Optimization terminated successfully.
#          Current function value: -4.615914
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.55534136  0.46334368 -0.06150216]
# rotation    : [-0.00334336 -0.00429548  0.01413848]
#
# Estimating motion at time frame 24/165...
# Optimization terminated successfully.
#          Current function value: -4.620174
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.42380282  0.57326506 -0.1392737 ]
# rotation    : [ 0.00014439  0.00038184  0.01249936]
#
# Estimating motion at time frame 25/165...
# Optimization terminated successfully.
#          Current function value: -4.624153
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.1873514   0.57559641  0.00871856]
# rotation    : [ 0.00546081  0.00081773  0.00856429]
#
# Estimating motion at time frame 26/165...
# Optimization terminated successfully.
#          Current function value: -4.626630
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.20981092  0.38829666 -0.06060685]
# rotation    : [ 0.00368442 -0.00058542  0.00827035]
#
# Estimating motion at time frame 27/165...
# Optimization terminated successfully.
#          Current function value: -4.631954
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [-0.33718185  0.30225867 -0.566443  ]
# rotation    : [ 0.00179048  0.00017218  0.00945334]
#
# Estimating motion at time frame 28/165...
# Optimization terminated successfully.
#          Current function value: -4.640699
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [-0.41938881  0.46441642 -0.82752759]
# rotation    : [-0.00092696 -0.00083692  0.00962009]
#
# Estimating motion at time frame 29/165...
# Optimization terminated successfully.
#          Current function value: -4.653412
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.57736262  0.72612053 -0.96654345]
# rotation    : [-0.00217171  0.0017032   0.01352671]
#
# Estimating motion at time frame 30/165...
# Optimization terminated successfully.
#          Current function value: -4.666526
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.64554673  0.68919948 -1.20506745]
# rotation    : [-0.00982705  0.00060581  0.01132536]
#
# Estimating motion at time frame 31/165...
# Optimization terminated successfully.
#          Current function value: -4.678905
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 11
#          Hessian evaluations: 11
# translation : [-0.51205033  0.51603247 -1.2038169 ]
# rotation    : [ -1.61427681e-02   9.56385297e-05   6.16462147e-03]
#
# Estimating motion at time frame 32/165...
# Optimization terminated successfully.
#          Current function value: -4.694393
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.33414465  0.30501557 -1.49235783]
# rotation    : [-0.02092963  0.00257132 -0.00047178]
#
# Estimating motion at time frame 33/165...
# Optimization terminated successfully.
#          Current function value: -4.722710
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [-0.51672851  0.65068965 -1.93675935]
# rotation    : [-0.0304582   0.00510316 -0.00083021]
#
# Estimating motion at time frame 34/165...
# Optimization terminated successfully.
#          Current function value: -4.744978
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 14
#          Hessian evaluations: 14
# translation : [-0.69331285  0.78168916 -1.72635745]
# rotation    : [-0.03206465  0.00231602  0.00246069]
#
# Estimating motion at time frame 35/165...
# Optimization terminated successfully.
#          Current function value: -4.752485
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.33615491  0.33126096 -0.768368  ]
# rotation    : [-0.01615131 -0.00445508  0.00279493]
#
# Estimating motion at time frame 36/165...
# Optimization terminated successfully.
#          Current function value: -4.759168
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.09964559  0.14117809 -0.84726975]
# rotation    : [-0.01860093 -0.00458698  0.00136122]
#
# Estimating motion at time frame 37/165...
# Optimization terminated successfully.
#          Current function value: -4.767505
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.03008078  0.17085917 -0.95847258]
# rotation    : [-0.02010483 -0.00374137 -0.00017631]
#
# Estimating motion at time frame 38/165...
# Optimization terminated successfully.
#          Current function value: -4.771614
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.10689516  0.28533051 -0.54184341]
# rotation    : [-0.00942615 -0.00818216  0.00623062]
#
# Estimating motion at time frame 39/165...
# Optimization terminated successfully.
#          Current function value: -4.774174
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [ 0.01629425  0.21317783 -0.24479102]
# rotation    : [-0.0051009  -0.00734624  0.00739643]
#
# Estimating motion at time frame 40/165...
# Optimization terminated successfully.
#          Current function value: -4.788161
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.03438258  0.51042601 -1.17573082]
# rotation    : [-0.0229348  -0.0024211   0.00570563]
#
# Estimating motion at time frame 41/165...
# Optimization terminated successfully.
#          Current function value: -4.810856
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.02767134  0.45220905 -1.50776988]
# rotation    : [-0.03016981 -0.00257839  0.00451918]
#
# Estimating motion at time frame 42/165...
# Optimization terminated successfully.
#          Current function value: -4.840597
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.0577059   0.66565725 -1.67267333]
# rotation    : [-0.0389476  -0.00204802  0.00639549]
#
# Estimating motion at time frame 43/165...
# Optimization terminated successfully.
#          Current function value: -4.860068
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 11
#          Hessian evaluations: 11
# translation : [-0.01754572  0.84678425 -0.95921261]
# rotation    : [-0.03040829  0.00091217  0.00615732]
#
# Estimating motion at time frame 44/165...
# Optimization terminated successfully.
#          Current function value: -4.875678
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 11
#          Hessian evaluations: 11
# translation : [ 0.24165758  0.45886942 -0.64611309]
# rotation    : [-0.02768916  0.00035594  0.00388151]
#
# Estimating motion at time frame 45/165...
# Optimization terminated successfully.
#          Current function value: -4.891994
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.36794707  0.31635203 -0.58027846]
# rotation    : [-0.0289637  -0.00120709  0.00407746]
#
# Estimating motion at time frame 46/165...
# Optimization terminated successfully.
#          Current function value: -4.910429
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.38214874  0.31656432 -0.64826818]
# rotation    : [-0.02973613 -0.00086476  0.00323788]
#
# Estimating motion at time frame 47/165...
# Optimization terminated successfully.
#          Current function value: -4.930067
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.2427472   0.40986635 -0.88918135]
# rotation    : [-0.03075592 -0.00103916  0.00421206]
#
# Estimating motion at time frame 48/165...
# Optimization terminated successfully.
#          Current function value: -4.942110
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.02624646  0.6055948  -0.69747851]
# rotation    : [-0.02097111 -0.00203187  0.00757713]
#
# Estimating motion at time frame 49/165...
# Optimization terminated successfully.
#          Current function value: -4.954190
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.0767826   0.49761779 -0.77615171]
# rotation    : [-0.02076243 -0.00349349  0.00941539]
#
# Estimating motion at time frame 50/165...
# Optimization terminated successfully.
#          Current function value: -4.960148
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.24296484  0.41744822 -0.38603954]
# rotation    : [-0.0101932  -0.00670868  0.0110145 ]
#
# Estimating motion at time frame 51/165...
# Optimization terminated successfully.
#          Current function value: -4.966914
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [ 0.03791695  0.26548934 -0.7088004 ]
# rotation    : [-0.01468468  0.00641259  0.00318678]
#
# Estimating motion at time frame 52/165...
# Optimization terminated successfully.
#          Current function value: -4.971706
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.14022253  0.29657127 -0.52346247]
# rotation    : [-0.01110064  0.00696798  0.00692444]
#
# Estimating motion at time frame 53/165...
# Optimization terminated successfully.
#          Current function value: -4.976626
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 11
#          Hessian evaluations: 11
# translation : [-0.43047751  0.5000351  -0.13840248]
# rotation    : [-0.00678561  0.00229763  0.009925  ]
#
# Estimating motion at time frame 54/165...
# Optimization terminated successfully.
#          Current function value: -4.979075
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.351466    0.31532624  0.05657942]
# rotation    : [ 0.00203573  0.00206987  0.00776286]
#
# Estimating motion at time frame 55/165...
# Optimization terminated successfully.
#          Current function value: -4.980979
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.23019257  0.06260064 -0.17567742]
# rotation    : [ 0.00114795  0.00310045  0.00854044]
#
# Estimating motion at time frame 56/165...
# Optimization terminated successfully.
#          Current function value: -4.985223
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.33974237  0.11070227 -0.35653451]
# rotation    : [-0.00367664  0.00444624  0.01163187]
#
# Estimating motion at time frame 57/165...
# Optimization terminated successfully.
#          Current function value: -4.990174
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.53198336  0.24885937 -0.01619752]
# rotation    : [-0.00286539  0.00280503  0.01348216]
#
# Estimating motion at time frame 58/165...
# Optimization terminated successfully.
#          Current function value: -4.994433
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.44973343  0.35093772 -0.36665966]
# rotation    : [-0.00442191 -0.00018544  0.01128082]
#
# Estimating motion at time frame 59/165...
# Optimization terminated successfully.
#          Current function value: -4.998451
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.11428402  0.2290396  -0.59846186]
# rotation    : [-0.00828224  0.0039764   0.00408755]
#
# Estimating motion at time frame 60/165...
# Optimization terminated successfully.
#          Current function value: -5.003338
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.15218729  0.14054938 -0.6161512 ]
# rotation    : [-0.01056493  0.0063202   0.00468175]
#
# Estimating motion at time frame 61/165...
# Optimization terminated successfully.
#          Current function value: -5.007314
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.19992818  0.26491799 -0.31477193]
# rotation    : [-0.01050234  0.00426611  0.0080358 ]
#
# Estimating motion at time frame 62/165...
# Optimization terminated successfully.
#          Current function value: -5.011668
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.14508464  0.2202774  -0.43391433]
# rotation    : [-0.01022459  0.00680499  0.00709133]
#
# Estimating motion at time frame 63/165...
# Optimization terminated successfully.
#          Current function value: -5.016421
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.06693608  0.2264567  -0.33245954]
# rotation    : [-0.00593513  0.01070801  0.00874692]
#
# Estimating motion at time frame 64/165...
# Optimization terminated successfully.
#          Current function value: -5.020747
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.09869627  0.25685887 -0.36602994]
# rotation    : [-0.00813004  0.00631241  0.00947577]
#
# Estimating motion at time frame 65/165...
# Optimization terminated successfully.
#          Current function value: -5.025209
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.12003421  0.20016327 -0.33475141]
# rotation    : [-0.01512859 -0.00314996  0.0047425 ]
#
# Estimating motion at time frame 66/165...
# Optimization terminated successfully.
#          Current function value: -5.032094
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.09486198  0.15695728 -0.09810446]
# rotation    : [-0.01585293 -0.00292735  0.004076  ]
#
# Estimating motion at time frame 67/165...
# Optimization terminated successfully.
#          Current function value: -5.040737
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.06534214  0.25079184 -0.52659344]
# rotation    : [-0.0190845  0.0010556  0.005226 ]
#
# Estimating motion at time frame 68/165...
# Optimization terminated successfully.
#          Current function value: -5.060554
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.1884565   0.32811361 -0.95207845]
# rotation    : [-0.0303786   0.00478383 -0.00237008]
#
# Estimating motion at time frame 69/165...
# Optimization terminated successfully.
#          Current function value: -5.071710
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.22575427  0.18834829 -0.78340582]
# rotation    : [-0.02445756  0.00297872 -0.00587764]
#
# Estimating motion at time frame 70/165...
# Optimization terminated successfully.
#          Current function value: -5.079744
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.11432323  0.2870059  -0.41595792]
# rotation    : [-0.01841162  0.00217953  0.00038862]
#
# Estimating motion at time frame 71/165...
# Optimization terminated successfully.
#          Current function value: -5.087830
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.03515707  0.27013199 -0.36816582]
# rotation    : [-0.01896208  0.00250837  0.00097761]
#
# Estimating motion at time frame 72/165...
# Optimization terminated successfully.
#          Current function value: -5.096474
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.03624644  0.22341252 -0.45700325]
# rotation    : [-0.01924444  0.00248758  0.00177874]
#
# Estimating motion at time frame 73/165...
# Optimization terminated successfully.
#          Current function value: -5.103590
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.00364649  0.30651408 -0.42053245]
# rotation    : [-0.01730496  0.00228298  0.00254649]
#
# Estimating motion at time frame 74/165...
# Optimization terminated successfully.
#          Current function value: -5.110806
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.04498475  0.26758504 -0.53212187]
# rotation    : [-0.01764694  0.0019255   0.00271734]
#
# Estimating motion at time frame 75/165...
# Optimization terminated successfully.
#          Current function value: -5.115739
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.03548602  0.24369055 -0.41970763]
# rotation    : [-0.01487826  0.00369223 -0.00092254]
#
# Estimating motion at time frame 76/165...
# Optimization terminated successfully.
#          Current function value: -5.120525
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.14878002  0.1332805  -0.31439796]
# rotation    : [-0.01361603  0.0059067  -0.00167422]
#
# Estimating motion at time frame 77/165...
# Optimization terminated successfully.
#          Current function value: -5.123653
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.09371163  0.13048696 -0.30815366]
# rotation    : [-0.01173421  0.00570487 -0.00068552]
#
# Estimating motion at time frame 78/165...
# Optimization terminated successfully.
#          Current function value: -5.125326
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.12302263  0.17037422 -0.14475587]
# rotation    : [-0.00879561  0.00485417  0.00043306]
#
# Estimating motion at time frame 79/165...
# Optimization terminated successfully.
#          Current function value: -5.126997
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.20073672  0.02110324  0.02543628]
# rotation    : [-0.00559507  0.00575582  0.00066937]
#
# Estimating motion at time frame 80/165...
# Optimization terminated successfully.
#          Current function value: -5.129230
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.22362667  0.05619134  0.04408858]
# rotation    : [-0.00504702  0.00758082  0.00080664]
#
# Estimating motion at time frame 81/165...
# Optimization terminated successfully.
#          Current function value: -5.130944
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.24322465  0.0191948   0.02939542]
# rotation    : [-0.00348669  0.00781179 -0.00024739]
#
# Estimating motion at time frame 82/165...
# Optimization terminated successfully.
#          Current function value: -5.132468
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.21333731  0.04451736  0.01480366]
# rotation    : [-0.00472497  0.00594057  0.00043683]
#
# Estimating motion at time frame 83/165...
# Optimization terminated successfully.
#          Current function value: -5.133975
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.2124121   0.07091085  0.06900181]
# rotation    : [-0.0050123   0.00467015  0.00039415]
#
# Estimating motion at time frame 84/165...
# Optimization terminated successfully.
#          Current function value: -5.135152
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.19472815  0.05542252  0.09263773]
# rotation    : [-0.00269059  0.00630834 -0.00106819]
#
# Estimating motion at time frame 85/165...
# Optimization terminated successfully.
#          Current function value: -5.136180
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.11439967  0.09643363  0.20702496]
# rotation    : [-0.00091252  0.0046238   0.00050391]
#
# Estimating motion at time frame 86/165...
# Optimization terminated successfully.
#          Current function value: -5.137989
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 11
#          Hessian evaluations: 11
# translation : [ 0.13024764  0.13051011  0.338716  ]
# rotation    : [  8.20035655e-05   3.84534749e-03  -3.00365798e-04]
#
# Estimating motion at time frame 87/165...
# Optimization terminated successfully.
#          Current function value: -5.140097
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.13196097  0.05214347  0.38471462]
# rotation    : [ 0.00088725  0.00383889 -0.00243237]
#
# Estimating motion at time frame 88/165...
# Optimization terminated successfully.
#          Current function value: -5.142062
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.14695015  0.06072543  0.35853498]
# rotation    : [ 0.00050763  0.0042428  -0.00166451]
#
# Estimating motion at time frame 89/165...
# Optimization terminated successfully.
#          Current function value: -5.143980
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.10111739  0.09357679  0.36587227]
# rotation    : [ 0.00086201  0.00424315 -0.00047932]
#
# Estimating motion at time frame 90/165...
# Optimization terminated successfully.
#          Current function value: -5.145462
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.08237744  0.09474376  0.33591446]
# rotation    : [ 0.00057706  0.00252981 -0.00046644]
#
# Estimating motion at time frame 91/165...
# Optimization terminated successfully.
#          Current function value: -5.147527
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.06004106  0.10430383  0.39003109]
# rotation    : [ 0.00040245  0.00283698  0.00010744]
#
# Estimating motion at time frame 92/165...
# Optimization terminated successfully.
#          Current function value: -5.149828
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.04568072  0.1021024   0.43508197]
# rotation    : [  2.15749190e-03   1.93756799e-03   4.56150750e-05]
#
# Estimating motion at time frame 93/165...
# Optimization terminated successfully.
#          Current function value: -5.151919
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.03184389  0.11451273  0.40772534]
# rotation    : [ 0.00171567  0.00225682 -0.00062805]
#
# Estimating motion at time frame 94/165...
# Optimization terminated successfully.
#          Current function value: -5.154330
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 11
#          Hessian evaluations: 11
# translation : [-0.0857121   0.15929587  0.45617214]
# rotation    : [ 0.00304631  0.00094944  0.00252089]
#
# Estimating motion at time frame 95/165...
# Optimization terminated successfully.
#          Current function value: -5.157264
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [-0.1857645   0.07171774  0.49829905]
# rotation    : [ 0.00513356  0.00151629  0.00407357]
#
# Estimating motion at time frame 96/165...
# Optimization terminated successfully.
#          Current function value: -5.160782
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.11874041  0.11624935  0.5493762 ]
# rotation    : [ 0.00526705  0.00154682  0.00042314]
#
# Estimating motion at time frame 97/165...
# Optimization terminated successfully.
#          Current function value: -5.164831
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 12
#          Hessian evaluations: 12
# translation : [-0.14907113  0.11111277  0.59772932]
# rotation    : [ 0.00541467  0.00081358  0.00079815]
#
# Estimating motion at time frame 98/165...
# Optimization terminated successfully.
#          Current function value: -5.167858
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [-0.16763648  0.13280297  0.48099235]
# rotation    : [ 0.00313484  0.00150227  0.00140115]
#
# Estimating motion at time frame 99/165...
# Optimization terminated successfully.
#          Current function value: -5.169578
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 12
#          Hessian evaluations: 12
# translation : [-0.20992873  0.19894454  0.25492397]
# rotation    : [-0.00109966  0.00095001  0.0036057 ]
#
# Estimating motion at time frame 100/165...
# Optimization terminated successfully.
#          Current function value: -5.172917
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 12
#          Hessian evaluations: 12
# translation : [-0.28456082  0.31035145  0.36104065]
# rotation    : [-0.00073521  0.00116901  0.00376236]
#
# Estimating motion at time frame 101/165...
# Optimization terminated successfully.
#          Current function value: -5.175465
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.23024857  0.27385844  0.34335417]
# rotation    : [ 0.00108206  0.00095973  0.00325826]
#
# Estimating motion at time frame 102/165...
# Optimization terminated successfully.
#          Current function value: -5.177704
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 11
#          Hessian evaluations: 11
# translation : [-0.23946729  0.17056478  0.36004878]
# rotation    : [ 0.00232938  0.00121399  0.00229301]
#
# Estimating motion at time frame 103/165...
# Optimization terminated successfully.
#          Current function value: -5.179566
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.24879366  0.1678244   0.28738043]
# rotation    : [ 0.00152579  0.00165107  0.00346773]
#
# Estimating motion at time frame 104/165...
# Optimization terminated successfully.
#          Current function value: -5.181127
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.22751049  0.15413019  0.2969806 ]
# rotation    : [ 0.00296715  0.00066488  0.00237906]
#
# Estimating motion at time frame 105/165...
# Optimization terminated successfully.
#          Current function value: -5.181440
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 11
#          Hessian evaluations: 11
# translation : [-0.07116334 -0.05400863  0.15323922]
# rotation    : [  2.50613385e-03   9.89688100e-04   2.41945412e-05]
#
# Estimating motion at time frame 106/165...
# Optimization terminated successfully.
#          Current function value: -5.181992
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.06189758 -0.10245824 -0.13268876]
# rotation    : [ 0.00180388  0.00203108 -0.00151685]
#
# Estimating motion at time frame 107/165...
# Optimization terminated successfully.
#          Current function value: -5.182834
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.13261374 -0.08544138 -0.04359519]
# rotation    : [ 0.00381581  0.00453263 -0.00254826]
#
# Estimating motion at time frame 108/165...
# Optimization terminated successfully.
#          Current function value: -5.183706
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.08722606 -0.09353235 -0.11942565]
# rotation    : [ 0.00315796  0.00299101 -0.00078888]
#
# Estimating motion at time frame 109/165...
# Optimization terminated successfully.
#          Current function value: -5.184241
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [-0.08682144 -0.03213201  0.05881763]
# rotation    : [ 0.00463712  0.00201322  0.00181375]
#
# Estimating motion at time frame 110/165...
# Optimization terminated successfully.
#          Current function value: -5.185162
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.23053399  0.04810216  0.02241856]
# rotation    : [ 0.00376068  0.00027435  0.00374774]
#
# Estimating motion at time frame 111/165...
# Optimization terminated successfully.
#          Current function value: -5.186186
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.22674828  0.0865131  -0.0196435 ]
# rotation    : [ 0.00163435 -0.0004905   0.005516  ]
#
# Estimating motion at time frame 112/165...
# Optimization terminated successfully.
#          Current function value: -5.187140
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.20996063  0.04189005  0.17241445]
# rotation    : [ 0.00475812 -0.00054539  0.00377891]
#
# Estimating motion at time frame 113/165...
# Optimization terminated successfully.
#          Current function value: -5.188680
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.21265103  0.06394834  0.2041157 ]
# rotation    : [ 0.00663554  0.00018057  0.00446846]
#
# Estimating motion at time frame 114/165...
# Optimization terminated successfully.
#          Current function value: -5.190413
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.21687779  0.11378839  0.17619405]
# rotation    : [ 0.00621499  0.00117899  0.00510588]
#
# Estimating motion at time frame 115/165...
# Optimization terminated successfully.
#          Current function value: -5.191819
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.22441563  0.11577459  0.24163775]
# rotation    : [ 0.00527831  0.00053835  0.00415513]
#
# Estimating motion at time frame 116/165...
# Optimization terminated successfully.
#          Current function value: -5.192875
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.23310268  0.12537227  0.17362731]
# rotation    : [ 0.00330106 -0.00032018  0.00357904]
#
# Estimating motion at time frame 117/165...
# Optimization terminated successfully.
#          Current function value: -5.194195
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.28052967  0.05221423  0.14796365]
# rotation    : [ 0.00449373 -0.00070628  0.00472806]
#
# Estimating motion at time frame 118/165...
# Optimization terminated successfully.
#          Current function value: -5.195530
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.2642679   0.03899682  0.14729018]
# rotation    : [ 0.0044765  -0.00193065  0.00521302]
#
# Estimating motion at time frame 119/165...
# Optimization terminated successfully.
#          Current function value: -5.197148
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.32251442  0.03447143  0.04896246]
# rotation    : [ 0.00369211 -0.00255655  0.00534715]
#
# Estimating motion at time frame 120/165...
# Optimization terminated successfully.
#          Current function value: -5.198589
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.31862137  0.01883374  0.01325947]
# rotation    : [ 0.00278509 -0.00195726  0.00527807]
#
# Estimating motion at time frame 121/165...
# Optimization terminated successfully.
#          Current function value: -5.200205
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.33615586  0.13243643  0.02236615]
# rotation    : [ 0.00140197 -0.00130542  0.00650249]
#
# Estimating motion at time frame 122/165...
# Optimization terminated successfully.
#          Current function value: -5.201406
#          Iterations: 11
#          Function evaluations: 12
#          Gradient evaluations: 11
#          Hessian evaluations: 11
# translation : [-0.29883477  0.03441109 -0.01767739]
# rotation    : [ 0.00168409 -0.00279951  0.00512113]
#
# Estimating motion at time frame 123/165...
# Optimization terminated successfully.
#          Current function value: -5.202985
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.3433442   0.02566026 -0.08620802]
# rotation    : [ 0.00043478 -0.00486924  0.00427414]
#
# Estimating motion at time frame 124/165...
# Optimization terminated successfully.
#          Current function value: -5.204642
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.36557061 -0.02925118 -0.04043974]
# rotation    : [ 0.00050994 -0.00487416  0.00411307]
#
# Estimating motion at time frame 125/165...
# Optimization terminated successfully.
#          Current function value: -5.205672
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [-0.28996404 -0.02351816  0.00368942]
# rotation    : [ 0.00156564 -0.0034155   0.0030917 ]
#
# Estimating motion at time frame 126/165...
# Optimization terminated successfully.
#          Current function value: -5.206750
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# ...
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.32619544 -0.01585925  0.06062361]
# rotation    : [ 0.00357269 -0.00285857  0.0061144 ]
#
# Estimating motion at time frame 121/165...
# Optimization terminated successfully.
#          Current function value: -5.304823
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.34310348  0.0976468   0.07200813]
# rotation    : [ 0.00222415 -0.00228978  0.00738724]
#
# Estimating motion at time frame 122/165...
# Optimization terminated successfully.
#          Current function value: -5.304835
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.30219898 -0.0018394   0.03042488]
# rotation    : [ 0.00244449 -0.00377757  0.0059335 ]
#
# Estimating motion at time frame 123/165...
# Optimization terminated successfully.
#          Current function value: -5.304848
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.34568366 -0.01052456 -0.03784448]
# rotation    : [ 0.00121492 -0.00577873  0.00502404]
#
# Estimating motion at time frame 124/165...
# Optimization terminated successfully.
#          Current function value: -5.304860
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.36603745 -0.06623031  0.01067406]
# rotation    : [ 0.00136839 -0.00579599  0.00486772]
#
# Estimating motion at time frame 125/165...
# Optimization terminated successfully.
#          Current function value: -5.304874
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [-0.28965122 -0.06165018  0.05646191]
# rotation    : [ 0.00245908 -0.00433181  0.00386191]
#
# Estimating motion at time frame 126/165...
# Optimization terminated successfully.
#          Current function value: -5.304887
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.2628901  -0.10359532  0.00866379]
# rotation    : [ 0.00246729 -0.00508732  0.00415484]
#
# Estimating motion at time frame 127/165...
# Optimization terminated successfully.
#          Current function value: -5.304898
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.28696578 -0.06542534  0.00163935]
# rotation    : [ 0.00149895 -0.00468334  0.00555828]
#
# Estimating motion at time frame 128/165...
# Optimization terminated successfully.
#          Current function value: -5.304910
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 7
#          Hessian evaluations: 7
# translation : [-0.27920934 -0.0396914   0.14681027]
# rotation    : [ 0.00181734 -0.00581386  0.00633013]
#
# Estimating motion at time frame 129/165...
# Optimization terminated successfully.
#          Current function value: -5.304923
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.23695768 -0.06280158  0.14726688]
# rotation    : [ 0.00226013 -0.00640186  0.00512106]
#
# Estimating motion at time frame 130/165...
# Optimization terminated successfully.
#          Current function value: -5.304935
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.28780988 -0.10859587  0.02823657]
# rotation    : [ 0.00206853 -0.0077611   0.00476204]
#
# Estimating motion at time frame 131/165...
# Optimization terminated successfully.
#          Current function value: -5.304949
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [-0.06027445 -0.14337003  0.10890576]
# rotation    : [ 0.00254626 -0.00509537  0.00067811]
#
# Estimating motion at time frame 132/165...
# Optimization terminated successfully.
#          Current function value: -5.304961
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.39762656 -0.20588974  0.26221406]
# rotation    : [ 0.00335152  0.00213358 -0.00416766]
#
# Estimating motion at time frame 133/165...
# Optimization terminated successfully.
#          Current function value: -5.304974
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.34232552 -0.22798927  0.22810933]
# rotation    : [ 0.00508791  0.00146045 -0.00393174]
#
# Estimating motion at time frame 134/165...
# Optimization terminated successfully.
#          Current function value: -5.304987
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.33368625 -0.22181609  0.13632703]
# rotation    : [ 0.00471031  0.00231016 -0.00435269]
#
# Estimating motion at time frame 135/165...
# Optimization terminated successfully.
#          Current function value: -5.304999
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.2034314  -0.32181704  0.03170774]
# rotation    : [ 0.00417691  0.00095394 -0.00445255]
#
# Estimating motion at time frame 136/165...
# Optimization terminated successfully.
#          Current function value: -5.305014
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.07887628 -0.24391957  0.13979942]
# rotation    : [ 0.00660425 -0.0008019  -0.00088174]
#
# Estimating motion at time frame 137/165...
# Optimization terminated successfully.
#          Current function value: -5.305029
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.05765892 -0.15841254  0.26809484]
# rotation    : [ 0.00716484 -0.00162219 -0.00101356]
#
# Estimating motion at time frame 138/165...
# Optimization terminated successfully.
#          Current function value: -5.305043
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.07478249 -0.19085912  0.20564657]
# rotation    : [ 0.00643819 -0.00275167 -0.00188366]
#
# Estimating motion at time frame 139/165...
# Optimization terminated successfully.
#          Current function value: -5.305058
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.03126598 -0.25741506  0.20148794]
# rotation    : [ 0.00649281 -0.0027534  -0.00044458]
#
# Estimating motion at time frame 140/165...
# Optimization terminated successfully.
#          Current function value: -5.305074
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.07315655 -0.21469238  0.23446324]
# rotation    : [ 0.00651778 -0.00221593 -0.00212189]
#
# Estimating motion at time frame 141/165...
# Optimization terminated successfully.
#          Current function value: -5.305089
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.08175077 -0.14831698  0.3211081 ]
# rotation    : [ 0.00620605 -0.00178787 -0.00219119]
#
# Estimating motion at time frame 142/165...
# Optimization terminated successfully.
#          Current function value: -5.305105
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.05799787 -0.1259932   0.24480885]
# rotation    : [ 0.00518081 -0.00264489 -0.00204464]
#
# Estimating motion at time frame 143/165...
# Optimization terminated successfully.
#          Current function value: -5.305122
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.03665365 -0.19201746  0.20765183]
# rotation    : [ 0.00560803 -0.00324665 -0.0009241 ]
#
# Estimating motion at time frame 144/165...
# Optimization terminated successfully.
#          Current function value: -5.305137
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.097811   -0.19480798  0.27041335]
# rotation    : [ 0.00583745 -0.00371628 -0.00168129]
#
# Estimating motion at time frame 145/165...
# Optimization terminated successfully.
#          Current function value: -5.305154
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.08519697 -0.19143918  0.22113511]
# rotation    : [ 0.00531441 -0.00437076 -0.00159438]
#
# Estimating motion at time frame 146/165...
# Optimization terminated successfully.
#          Current function value: -5.305170
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.0942886  -0.19957983  0.27242434]
# rotation    : [ 0.00613905 -0.0033733  -0.00140512]
#
# Estimating motion at time frame 147/165...
# Optimization terminated successfully.
#          Current function value: -5.305185
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.21257674 -0.21203405  0.24644931]
# rotation    : [ 0.00528746 -0.00224768 -0.00442487]
#
# Estimating motion at time frame 148/165...
# Optimization terminated successfully.
#          Current function value: -5.305201
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.21860225 -0.22330336  0.27585998]
# rotation    : [ 0.00579749 -0.0017191  -0.00305114]
#
# Estimating motion at time frame 149/165...
# Optimization terminated successfully.
#          Current function value: -5.305216
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.22739676 -0.2669474   0.12276399]
# rotation    : [ 0.00507123 -0.00072779 -0.00423926]
#
# Estimating motion at time frame 150/165...
# Optimization terminated successfully.
#          Current function value: -5.305232
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.19178626 -0.28053718  0.06591519]
# rotation    : [ 0.00462535 -0.00209141 -0.00351513]
#
# Estimating motion at time frame 151/165...
# Optimization terminated successfully.
#          Current function value: -5.305249
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.2116544  -0.24002183  0.09387076]
# rotation    : [ 0.00418771 -0.0020176  -0.00342482]
#
# Estimating motion at time frame 152/165...
# Optimization terminated successfully.
#          Current function value: -5.305266
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.18722633 -0.26067732  0.17385806]
# rotation    : [ 0.00487535 -0.00454945 -0.0027106 ]
#
# Estimating motion at time frame 153/165...
# Optimization terminated successfully.
#          Current function value: -5.305283
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.19271248 -0.21386949  0.19780447]
# rotation    : [ 0.00436355 -0.00433502 -0.00298038]
#
# Estimating motion at time frame 154/165...
# Optimization terminated successfully.
#          Current function value: -5.305299
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.18532736 -0.28207333  0.10289794]
# rotation    : [ 0.00393462 -0.003511   -0.00342629]
#
# Estimating motion at time frame 155/165...
# Optimization terminated successfully.
#          Current function value: -5.305316
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.15520415 -0.26848519  0.09749846]
# rotation    : [ 0.00511504 -0.00332012 -0.00317652]
#
# Estimating motion at time frame 156/165...
# Optimization terminated successfully.
#          Current function value: -5.305332
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.12100929 -0.25161839  0.06715268]
# rotation    : [ 0.00528836 -0.00366075 -0.00336447]
#
# Estimating motion at time frame 157/165...
# Optimization terminated successfully.
#          Current function value: -5.305349
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.09126289 -0.22548217  0.11671551]
# rotation    : [ 0.00484624 -0.00559246 -0.00357111]
#
# Estimating motion at time frame 158/165...
# Optimization terminated successfully.
#          Current function value: -5.305366
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.15813702 -0.1784511   0.17817467]
# rotation    : [ 0.00563274 -0.00401369 -0.00436614]
#
# Estimating motion at time frame 159/165...
# Optimization terminated successfully.
#          Current function value: -5.305382
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.2452273  -0.23310375  0.19417168]
# rotation    : [ 0.0072375  -0.00296763 -0.00421583]
#
# Estimating motion at time frame 160/165...
# Optimization terminated successfully.
#          Current function value: -5.305401
#          Iterations: 10
#          Function evaluations: 11
#          Gradient evaluations: 10
#          Hessian evaluations: 10
# translation : [ 0.20804021 -0.28350381  0.19741473]
# rotation    : [ 0.00678798 -0.00333819 -0.00374911]
#
# Estimating motion at time frame 161/165...
# Optimization terminated successfully.
#          Current function value: -5.305418
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.19215123 -0.25737435  0.16462522]
# rotation    : [ 0.00541232 -0.00293831 -0.00473016]
#
# Estimating motion at time frame 162/165...
# Optimization terminated successfully.
#          Current function value: -5.305435
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.19248955 -0.25540017  0.1563702 ]
# rotation    : [ 0.00575859 -0.00307421 -0.00482562]
#
# Estimating motion at time frame 163/165...
# Optimization terminated successfully.
#          Current function value: -5.305450
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 8
#          Hessian evaluations: 8
# translation : [ 0.23361036 -0.22648752  0.19676788]
# rotation    : [ 0.00639823 -0.00300088 -0.00468053]
#
# Estimating motion at time frame 164/165...
# Optimization terminated successfully.
#          Current function value: -5.305467
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 9
#          Hessian evaluations: 9
# translation : [ 0.27806854 -0.27203509  0.26734929]
# rotation    : [ 0.00818969 -0.00091006 -0.00451695]
#
# Estimating motion at time frame 165/165...
# Optimization terminated successfully.
#          Current function value: -5.305482
#          Iterations: 12
#          Function evaluations: 13
#          Gradient evaluations: 12
#          Hessian evaluations: 12
# translation : [ 0.23671004 -0.27245481 -0.0411332 ]
# rotation    : [-0.00352039 -0.00268028 -0.01034503]

# %% [markdown]
# Plot the motion parameters.

# %%
# WRITEME

# %% [markdown]
# Resample the data using the motion parameters that we just computed

# %%
worst_bold_img_mc = realign.resample()
# Out:
# Gridding...
# Fully resampling scan 1/165
# Fully resampling scan 2/165
# Fully resampling scan 3/165
# Fully resampling scan 4/165
# Fully resampling scan 5/165
# Fully resampling scan 6/165
# Fully resampling scan 7/165
# Fully resampling scan 8/165
# Fully resampling scan 9/165
# Fully resampling scan 10/165
# Fully resampling scan 11/165
# Fully resampling scan 12/165
# Fully resampling scan 13/165
# Fully resampling scan 14/165
# Fully resampling scan 15/165
# Fully resampling scan 16/165
# Fully resampling scan 17/165
# Fully resampling scan 18/165
# Fully resampling scan 19/165
# Fully resampling scan 20/165
# Fully resampling scan 21/165
# Fully resampling scan 22/165
# Fully resampling scan 23/165
# Fully resampling scan 24/165
# Fully resampling scan 25/165
# Fully resampling scan 26/165
# Fully resampling scan 27/165
# Fully resampling scan 28/165
# Fully resampling scan 29/165
# Fully resampling scan 30/165
# Fully resampling scan 31/165
# Fully resampling scan 32/165
# Fully resampling scan 33/165
# Fully resampling scan 34/165
# Fully resampling scan 35/165
# Fully resampling scan 36/165
# Fully resampling scan 37/165
# Fully resampling scan 38/165
# Fully resampling scan 39/165
# Fully resampling scan 40/165
# Fully resampling scan 41/165
# Fully resampling scan 42/165
# Fully resampling scan 43/165
# Fully resampling scan 44/165
# Fully resampling scan 45/165
# Fully resampling scan 46/165
# Fully resampling scan 47/165
# Fully resampling scan 48/165
# Fully resampling scan 49/165
# Fully resampling scan 50/165
# Fully resampling scan 51/165
# Fully resampling scan 52/165
# Fully resampling scan 53/165
# Fully resampling scan 54/165
# Fully resampling scan 55/165
# Fully resampling scan 56/165
# Fully resampling scan 57/165
# Fully resampling scan 58/165
# Fully resampling scan 59/165
# Fully resampling scan 60/165
# Fully resampling scan 61/165
# Fully resampling scan 62/165
# Fully resampling scan 63/165
# Fully resampling scan 64/165
# Fully resampling scan 65/165
# Fully resampling scan 66/165
# Fully resampling scan 67/165
# Fully resampling scan 68/165
# Fully resampling scan 69/165
# Fully resampling scan 70/165
# Fully resampling scan 71/165
# Fully resampling scan 72/165
# Fully resampling scan 73/165
# Fully resampling scan 74/165
# Fully resampling scan 75/165
# Fully resampling scan 76/165
# Fully resampling scan 77/165
# Fully resampling scan 78/165
# Fully resampling scan 79/165
# Fully resampling scan 80/165
# Fully resampling scan 81/165
# Fully resampling scan 82/165
# Fully resampling scan 83/165
# Fully resampling scan 84/165
# Fully resampling scan 85/165
# Fully resampling scan 86/165
# Fully resampling scan 87/165
# Fully resampling scan 88/165
# Fully resampling scan 89/165
# Fully resampling scan 90/165
# Fully resampling scan 91/165
# Fully resampling scan 92/165
# Fully resampling scan 93/165
# Fully resampling scan 94/165
# Fully resampling scan 95/165
# Fully resampling scan 96/165
# Fully resampling scan 97/165
# Fully resampling scan 98/165
# Fully resampling scan 99/165
# Fully resampling scan 100/165
# Fully resampling scan 101/165
# Fully resampling scan 102/165
# Fully resampling scan 103/165
# Fully resampling scan 104/165
# Fully resampling scan 105/165
# Fully resampling scan 106/165
# Fully resampling scan 107/165
# Fully resampling scan 108/165
# Fully resampling scan 109/165
# Fully resampling scan 110/165
# Fully resampling scan 111/165
# Fully resampling scan 112/165
# Fully resampling scan 113/165
# Fully resampling scan 114/165
# Fully resampling scan 115/165
# Fully resampling scan 116/165
# Fully resampling scan 117/165
# Fully resampling scan 118/165
# Fully resampling scan 119/165
# Fully resampling scan 120/165
# Fully resampling scan 121/165
# Fully resampling scan 122/165
# Fully resampling scan 123/165
# Fully resampling scan 124/165
# Fully resampling scan 125/165
# Fully resampling scan 126/165
# Fully resampling scan 127/165
# Fully resampling scan 128/165
# Fully resampling scan 129/165
# Fully resampling scan 130/165
# Fully resampling scan 131/165
# Fully resampling scan 132/165
# Fully resampling scan 133/165
# Fully resampling scan 134/165
# Fully resampling scan 135/165
# Fully resampling scan 136/165
# Fully resampling scan 137/165
# Fully resampling scan 138/165
# Fully resampling scan 139/165
# Fully resampling scan 140/165
# Fully resampling scan 141/165
# Fully resampling scan 142/165
# Fully resampling scan 143/165
# Fully resampling scan 144/165
# Fully resampling scan 145/165
# Fully resampling scan 146/165
# Fully resampling scan 147/165
# Fully resampling scan 148/165
# Fully resampling scan 149/165
# Fully resampling scan 150/165
# Fully resampling scan 151/165
# Fully resampling scan 152/165
# Fully resampling scan 153/165
# Fully resampling scan 154/165
# Fully resampling scan 155/165
# Fully resampling scan 156/165
# Fully resampling scan 157/165
# Fully resampling scan 158/165
# Fully resampling scan 159/165
# Fully resampling scan 160/165
# Fully resampling scan 161/165
# Fully resampling scan 162/165
# Fully resampling scan 163/165
# Fully resampling scan 164/165
# Fully resampling scan 165/165

# %%
worst_arr_mc = worst_bold_img_mc[0].get_data()
worst_rms_mc = np.zeros(num_timepoints)
for t in range(num_timepoints):
    worst_rms_mc[t] = np.sqrt(np.mean((worst_arr_mc.mean(axis=3) - worst_arr_mc[:,:,:,t])**2))

# %% [markdown]
# Now plot the results, comparing to the uncorrected RMS.

# %%
plt.plot(rms_all[worst_subject])
plt.plot(worst_rms_mc)
legend(('uncorrected RMS','corrected RMS'))

# %% [markdown]
# Here's the code to run the realignment and resampling on all the subects. It takes a while to run, so we ran it earlier and saved the results to use below.

# %%
# WRITEME

# %% [markdown]
# Physio-- run retroicor to compute physio regressors on a sample dataset. Do a GLM to find the regions correlated with the physio regressors. Explain the problems (subject motion, interleaved slices) and the two ways to use the regressiors (physio-correct data up front or put regressors in a glm). There are issues with both. Might be important for resting state data. For task data, might be best to learn to live with physio noise.

# %%
# code here
